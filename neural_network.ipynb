# %%
import numpy as np

# %matplotlib inline
# %config InlineBackend.print_figure_kwargs={'facecolor' : "w"}
from matplotlib import pyplot as plt
plt.style.use(['seaborn-darkgrid'])
plt.rcParams['figure.figsize'] = (20, 9)
plt.rcParams['font.family'] = 'DejaVu Sans'
plt.rcParams['font.size'] = 20

# %%
class NeuralNetwork():
    """
    Modelo de red neuronal simple con numpy
    """
    W1_1 = None # weights from neuron 1 layer 1
    W2_1 = None # weights from neuron 2 layer 1
    W1_2 = None # weights from neuron 1 layer 2
    
    def __init__(self):
        pass
    
    
    def sigmoid(self, x):
        g_x = 1 / (1 + np.exp(-x))
        return g_x
        
        
    def fit(self, X, y, lr=0.1, epochs=20000):
        
        # MSE over epochs
        mse_epoch = []
        
        # Add a column fill with 1s to X to allow the vectorized calculation
        X = np.append(X, np.ones(shape=(X.shape[0],1)), axis = 1) 
        
        n = X.shape[0] # number of samples
        m = X.shape[1] # number of features
        
        # initialize weights random
        W1_1 = np.random.random(size=(m, 1))
        W2_1 = np.random.random(size=(m,1))
        W1_2 = np.random.random(size=(3,1))
        
        # iterate over the n_epochs
        for j in range(epochs):

            # Shuffle all the samples 
            idx = np.random.permutation(X.shape[0])
            X = X[idx]
            y = y[idx]
            
            # Reset the loss function
            mse=0

            # Iterate over the dataset
            for i in range(n):

                # Forward propagation
                z1 = X[i,:]@W1_1
                z1 = z1[0]
                a1 = self.sigmoid(z1)
                
                z2 = X[i,:]@W2_1
                z2 = z2[0]
                a2 = self.sigmoid(z2)
                
                x1_2 = np.array([a1,a2,1])
                z3 = x1_2@W1_2
                z3 = z3[0]
                a3 = self.sigmoid(z3)
                
                prediction = a3
                
                # Calculate the error 
                error = np.power(y[i] - prediction,2)
                # Acumulate loss
                mse = mse + error
                
                # Calculate the gradient
                grad_W1_2 = (-2/n) * (y[i] - prediction) * self.sigmoid(z3) * (1-self.sigmoid(z3)) * x1_2
                grad_W2_1 = (-2/n) * (y[i] - prediction) * self.sigmoid(z3) * (1-self.sigmoid(z3)) * W1_2[1] * \
                            self.sigmoid(z2) * (1-self.sigmoid(z2)) * X[i,:]
                grad_W1_1 = (-2/n) * (y[i] - prediction) * self.sigmoid(z3) * (1-self.sigmoid(z3)) * W1_2[0] * \
                            self.sigmoid(z1) * (1-self.sigmoid(z1)) * X[i,:]
                
                # Back propagation
                W1_2 = W1_2 - (lr * grad_W1_2[:,np.newaxis])
                W2_1 = W2_1 - (lr * grad_W2_1[:,np.newaxis])
                W1_1 = W1_1 - (lr * grad_W1_1[:,np.newaxis])
            
            # Calculate mse
            mse_epoch.append(mse/4)
            
            # Print mse over epochs/10
            if (j % (epochs/10)) == 0:
                print("Epoch ",j," MSE: ",mse)
        
        # Save training parameters in class variables
        self.W1_1 = W1_1
        self.W2_1 = W2_1
        self.W1_2 = W1_2
        
        return mse_epoch
    
    def predict(self,X):
        
        # Add a column fill with 1s to X to allow the vectorized calculation
        X=np.append(X, np.ones(shape=(X.shape[0],1)), axis = 1)
        n = X.shape[0]
        
        prediction = []
        
        # Iterate over the dataset
        for i in range(n):
            # Forward propagation
            z1 = X[i,:]@self.W1_1
            z1 = z1[0]
            a1 = self.sigmoid(z1)
            
            z2 = X[i,:]@self.W2_1
            z2 = z2[0]
            a2 = self.sigmoid(z2)
            
            x1_2 = np.array([a1,a2,1])
            z3 = x1_2@self.W1_2
            z3 = z3[0]
            a3 = self.sigmoid(z3)
            
            prediction.append(a3)

        return np.array(prediction)

# %%
# Dataset
X = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([0,1,1,0])

# Model training
model = NeuralNetwork()
mse_epoch = model.fit(X,y)
# Out:
# Epoch  0  MSE:  1.037473834584305
# Epoch  2000  MSE:  0.9949041464983556
# Epoch  4000  MSE:  0.9237299641100571
# Epoch  6000  MSE:  0.726353472867504
# Epoch  8000  MSE:  0.35722624400921965
# Epoch  10000  MSE:  0.09233414756674121
# Epoch  12000  MSE:  0.04273917647949773
# Epoch  14000  MSE:  0.026446734149941455
# Epoch  16000  MSE:  0.01878430220498694
# Epoch  18000  MSE:  0.01442637011169195

# %%
# Training MSE plot
plt.plot(mse_epoch)

# %%
# Predictions over training dataset
print(f'Real: {y}')
print(f'Predicted: {model.predict(X)}')
# Out:
# Real: [0 1 1 0]
# Predicted: [0.05648276 0.94829591 0.94824461 0.05566211]

# %%
class NeuralNetworkMiniBatch():
    """
    Modelo de red neuronal simple con numpy
    """
    W1_1 = None # weights from neuron 1 layer 1
    W2_1 = None # weights from neuron 2 layer 1
    W1_2 = None # weights from neuron 1 layer 2
    
    def __init__(self):
        pass
    
    
    def sigmoid(self, x):
        g_x = 1 / (1 + np.exp(-x))
        return g_x
        
        
    def fit(self, X, y, lr=0.1, epochs=20000):
        
        # MSE over epochs
        mse_epoch = []
        
        # Add a column fill with 1s to X to allow the vectorized calculation
        X = np.append(X, np.ones(shape=(X.shape[0],1)), axis = 1) 
        
        n = X.shape[0] # number of samples
        m = X.shape[1] # number of features
        
        # initialize weights random
        W1_1 = np.random.random(size=(m, 1))
        W2_1 = np.random.random(size=(m,1))
        W1_2 = np.random.random(size=(3,1))
        
        b = 2
        n = 4
        batches =(int) (n / b)
        epsilon = 0.1

        # iterate over the n_epochs
        for j in range(epochs):

            # Shuffle all the samples 
            idx = np.random.permutation(X.shape[0])
            X = X[idx]
            y = y[idx]
            
            # Reset the loss function
            mse=0

            # Iterate over the dataset
            for i in range(batches):
                inferior = i*b
                superior = i*b + b

                # Forward propagation
                z1 = X[inferior:superior,:]@W1_1
                a1 = np.array([self.sigmoid(z1_i) for z1_i in z1])
                
                z2 = X[inferior:superior,:]@W2_1
                a2 = np.array([self.sigmoid(z2_i) for z2_i in z2])

                x1_2 = np.array([a1,a2, 1], dtype=object)
                z3 = x1_2@W1_2
                a3 = np.array([self.sigmoid(z3_i) for z3_i in z3])
                
                prediction = a3
                
                # Calculate the error 
                error = np.power(y[inferior:superior] - prediction,2)
                # Acumulate loss
                mse = mse + error
                
                # Calculate the gradient
                grad_W1_2 = (-2/b) * (y[inferior:superior] - prediction) * a3 * (np.ones(2)-a3) * x1_2[0:2]
                grad_W2_1 = (-2/b) * (y[inferior:superior] - prediction) * a3 * (np.ones(2)-a3) * np.array([W1_2[1], W1_2[1]]) * \
                            a2 * (np.ones(2)-a2) * X[inferior:superior,:]
                grad_W1_1 = (-2/b) * (y[inferior:superior] - prediction) * a3 * (np.ones(2)-a3) * np.array([W1_2[0], W1_2[0]]) * \
                            a2 * (np.ones(2)-a2) * X[inferior:superior,:]
                
                # Back propagation
                W1_2 = W1_2 - (lr * grad_W1_2[:,np.newaxis])
                W2_1 = W2_1 - (lr * grad_W2_1[:,np.newaxis])
                W1_1 = W1_1 - (lr * grad_W1_1[:,np.newaxis])
            
            # Calculate mse
            mse_epoch.append(mse/b)
            
            # Print mse over epochs/10
            if (j % (epochs/10)) == 0:
                print("Epoch ",j," MSE: ",mse)
        
        # Save training parameters in class variables
        self.W1_1 = W1_1
        self.W2_1 = W2_1
        self.W1_2 = W1_2
        
        return mse_epoch
    
    def predict(self,X):
        
        # Add a column fill with 1s to X to allow the vectorized calculation
        X=np.append(X, np.ones(shape=(X.shape[0],1)), axis = 1)
        n = X.shape[0]
        
        prediction = []
        
        # Iterate over the dataset
        for i in range(n):
            # Forward propagation
            z1 = X[i,:]@self.W1_1
            z1 = z1[0]
            a1 = self.sigmoid(z1)
            
            z2 = X[i,:]@self.W2_1
            z2 = z2[0]
            a2 = self.sigmoid(z2)
            
            x1_2 = np.array([a1,a2,1])
            z3 = x1_2@self.W1_2
            z3 = z3[0]
            a3 = self.sigmoid(z3)
            
            prediction.append(a3)

        return np.array(prediction)

# %%
# Dataset
X = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([0,1,1,0])

# Model training
model = NeuralNetworkMiniBatch()
mse_epoch = model.fit(X,y)
# Training MSE plot
plt.plot(mse_epoch)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/ezefernandez/dev/python/ceia/practicas/deep_learning/neural_network.ipynb Celda 7 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/Users/ezefernandez/dev/python/ceia/practicas/deep_learning/neural_network.ipynb#X21sZmlsZQ%3D%3D?line=4'>5</a> # Model training
#       <a href='vscode-notebook-cell:/Users/ezefernandez/dev/python/ceia/practicas/deep_learning/neural_network.ipynb#X21sZmlsZQ%3D%3D?line=5'>6</a> model = NeuralNetworkMiniBatch()
# ----> <a href='vscode-notebook-cell:/Users/ezefernandez/dev/python/ceia/practicas/deep_learning/neural_network.ipynb#X21sZmlsZQ%3D%3D?line=6'>7</a> mse_epoch = model.fit(X,y)
#       <a href='vscode-notebook-cell:/Users/ezefernandez/dev/python/ceia/practicas/deep_learning/neural_network.ipynb#X21sZmlsZQ%3D%3D?line=7'>8</a> # Training MSE plot
#       <a href='vscode-notebook-cell:/Users/ezefernandez/dev/python/ceia/practicas/deep_learning/neural_network.ipynb#X21sZmlsZQ%3D%3D?line=8'>9</a> plt.plot(mse_epoch)
#
# /Users/ezefernandez/dev/python/ceia/practicas/deep_learning/neural_network.ipynb Celda 7 in NeuralNetworkMiniBatch.fit(self, X, y, lr, epochs)
#      <a href='vscode-notebook-cell:/Users/ezefernandez/dev/python/ceia/practicas/deep_learning/neural_network.ipynb#X21sZmlsZQ%3D%3D?line=72'>73</a> # Calculate the gradient
#      <a href='vscode-notebook-cell:/Users/ezefernandez/dev/python/ceia/practicas/deep_learning/neural_network.ipynb#X21sZmlsZQ%3D%3D?line=73'>74</a> grad_W1_2 = (-2/b) * (y[inferior:superior] - prediction) * a3 * (np.ones(2)-a3) * x1_2[0:2]
# ---> <a href='vscode-notebook-cell:/Users/ezefernandez/dev/python/ceia/practicas/deep_learning/neural_network.ipynb#X21sZmlsZQ%3D%3D?line=74'>75</a> grad_W2_1 = (-2/b) * (y[inferior:superior] - prediction) * a3 * (np.ones(2)-a3) * np.array([W1_2[1], W1_2[1]]) * \
#      <a href='vscode-notebook-cell:/Users/ezefernandez/dev/python/ceia/practicas/deep_learning/neural_network.ipynb#X21sZmlsZQ%3D%3D?line=75'>76</a>             a2 * (np.ones(2)-a2) * X[inferior:superior,:]
#      <a href='vscode-notebook-cell:/Users/ezefernandez/dev/python/ceia/practicas/deep_learning/neural_network.ipynb#X21sZmlsZQ%3D%3D?line=76'>77</a> grad_W1_1 = (-2/b) * (y[inferior:superior] - prediction) * a3 * (np.ones(2)-a3) * np.array([W1_2[0], W1_2[0]]) * \
#      <a href='vscode-notebook-cell:/Users/ezefernandez/dev/python/ceia/practicas/deep_learning/neural_network.ipynb#X21sZmlsZQ%3D%3D?line=77'>78</a>             a2 * (np.ones(2)-a2) * X[inferior:superior,:]
#      <a href='vscode-notebook-cell:/Users/ezefernandez/dev/python/ceia/practicas/deep_learning/neural_network.ipynb#X21sZmlsZQ%3D%3D?line=79'>80</a> # Back propagation
#
# ValueError: operands could not be broadcast together with shapes (1,2,2) (2,3)
